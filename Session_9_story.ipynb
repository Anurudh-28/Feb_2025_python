# %%
#story

#son: hi papa
#fa: hi beta
#son: iam going to school
#fa:okay beta,i heard about the results came out
#son: yes papa
#fa:  what about the result
#son: lets play the game ill give the marks tell me the percentage
#fa: excited
#teluguu

# %%
from random import randint
from math import ceil
from time import sleep
str1=input("son:")
sleep(1)
str2=input("father:")
sleep(1)
str3=input("son:")
sleep(1)
str4=input("father:")
sleep(1)
str5=input("son:")
sleep(1)
str6=input("father:")
sleep(1)
str7=input("son:")
sleep(1)
str8=input("father:")
sleep(1)

telugu=randint(70,80)
hindi=randint(80,90)
maths=randint(90,95)
physics=randint(70,80)
biology=randint(80,85)
social=randint(90,97)

print(f"the marks are {telugu},{hindi},{maths},{physics},{biology},{social}")


percentage=((telugu+hindi+maths+physics+biology+social)/600)*100
print(f"father: the perentage is : {percentage}")


import math
math.ceil(percentage)

sleep(2)

str9=input("son:")

# %%
from random import randint
from math import ceil
from time import sleep

str1=input("son:")
sleep(1)
str2=input("father:")
sleep(1)
str3=input("son:")
sleep(1)
str4=input("father:")
sleep(1)
str5=input("son:")
sleep(1)
str6=input("father:")
sleep(1)
str7=input("son:")
sleep(1)
str8=input("father:")
sleep(1)

telugu=randint(70,80)
hindi=randint(80,90)
maths=randint(90,95)
physics=randint(70,80)
biology=randint(80,85)
social=randint(90,97)

print(f"the marks are {telugu},{hindi},{maths},{physics},{biology},{social}")


percentage=((telugu+hindi+maths+physics+biology+social)/600)*100
print(f"father: the perentage is : {percentage}")

import math
math.ceil(percentage)

sleep(2)

str9=input("son:")
