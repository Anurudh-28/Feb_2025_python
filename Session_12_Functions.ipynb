# %% [markdown]
# **Function**
#
#  -  reuse of the code block
#
#  -  function also called as mehtod
#
#  -  function with out arguments
#
#  -  function with arguments
#
#  -  function with default arguments
#
#  -  function with keyword arguments (kwargs)
#
#  -  function with global and local varaiable
#
#  -  function with return
#
#  -  function in function

# %% [markdown]
# ## functions without arguments

# %%
# syntax
def <function name>():
    <write your lines here>

# %%
num1=100
num2=200
add=num1+num2
print(f'the addition of {num1} and {num2} is:{add}')
# Out:
# the addition of 100 and 200 is:300

# %%
def addition():
        num1=eval(input('enter the num1:'))
        num2=eval(input('enter the num2:'))
        add=num1+num2
        print(f'the addition of {num1} and {num2} is:{add}')

# %% [markdown]
# **call the functions**

# %%
addition()
# Out:
# enter the num1: 1
# enter the num2: 2
# the addition of 1 and 2 is:3

# %%
def addition():
        num1=eval(input('enter the num1:'))
        num2=eval(input('enter the num2:'))
        add=num1+num2
        print(f'the addition of {num1} and {num2} is:{add}')

addition()
# Out:
# enter the num1: 1
# enter the num2: 4
# the addition of 1 and 4 is:5

# %%
def subraction():
        num1=eval(input('enter the num1:'))
        num2=eval(input('enter the num2:'))
        sub=num1-num2
        print(f'the subraction of {num1} and {num2} is:{sub}')

# %%
subraction()
# Out:
# enter the num1: 20
# enter the num2: 10
# the subraction of 20 and 10 is:10

# %% [markdown]
# **Rules**
#
#  -  functions name rules same as variable rules
#
#      -  no special characters and no numbers before
#
#      -  no space between words etc
#
#  -   function name should not be any keyword
#
#  -   function name should not be any package name
#
#  -   function name should not be any notebook name
#
#  -   function name should not be any variable which is using inside the function

# %%
def addition1():
        n1=eval(input('enter the num1:'))
        n2=eval(input('enter the num2:'))
        add1=n1+n2
        print(f'the addition of {n1} and {n2} is:{add1}')

# %%
addition1()
# Out:
# enter the num1: 1
# enter the num2: 1
# the addition of 1 and 1 is:2

# %% [markdown]
# -  while defining the fu ction we doesnot know whether the error is there or not
#
# -  for that we need to call the function

# %%
try:
    def addition2():
        n1=eval(input('enter the num1:'))
        n22=eval(input('enter the num2:'))
        add1=n1+n2
        print(f'the addition of {n1} and {n2} is:{add1}')

except exception as e:
    print(e)

# %%
addition2()
# Out:
# enter the num1: 1
# enter the num2: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 addition2()
#
# Cell In[57], line 5, in addition2()
#       3 n1=eval(input('enter the num1:'))
#       4 n22=eval(input('enter the num2:'))
# ----> 5 add1=n1+n2
#       6 print(f'the addition of {n1} and {n2} is:{add1}')
#
# NameError: name 'n2' is not defined

# %%
def addition3():
       try:
            n1=eval(input('enter the num1:'))
            n2=eval(input('enter the num2:'))
            add1=n11+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)
addition3()
# Out:
# enter the num1: 30
# enter the num2: 40
# name 'n11' is not defined

# %% [markdown]
# -  always try and except should be inside the def for the code only

# %% [markdown]
# **examples**

# %%
def AVG():     
    n1=eval(input("enter var1") ) #n1= '100'
    n2=eval(input("enter var2"))  #n2= '200'
    n3=eval(input("enter var3"))
    avg=(n1+n2+n3)/3
    print (f"average of numbers is: {avg}") 

AVG()
# Out:
# enter var1 1
# enter var2 4
# enter var3 5
# average of numbers is: 3.3333333333333335

# %%
def CITY():
    
    str1=input("enter name: ")
    str2=input("enter age: ")
    str3=input("enter city:")
    
    print(f"my name is {str1} iam {str2} years old i came from {str3}")

CITY()
# Out:
# enter name:  anu
# enter age:  22
# enter city: hyd
# my name is anu iam 22 years old i came from hyd

# %%
def CIRCLE():
    
    r=eval(input("radius:"))
    pi=3.14
    a=pi*r*r
    print(f"area of circle is:{a}")

CIRCLE()
# Out:
# radius: 2
# area of circle is:12.56

# %%
def TRIANGLE():

    
        L=eval(input("len of triangle:"))
        h=eval(input("height of triangle:"))
        a=0.5*L*h
        print(f"area of triangle is:{a}")

TRIANGLE()
# Out:
# len of triangle: 1
# height of triangle: 2
# area of triangle is:1.0

# %%
def BILL():
    bill_amount=eval(input("enter the bill amount"))
    tip_amount=eval(input("enter the tip amount"))
    total_amount= bill_amount+tip_amount
    print(f"Total bill paid is:{total_amount}")

BILL()
# Out:
# enter the bill amount 20
# enter the tip amount 1
# Total bill paid is:21

# %%
def RECTANGLE():
    
    L=eval(input("len of rectangle:"))
    b=eval(input("brd of rectangle:"))
    a=L*b
    print(f"area of rectangle is:{a}")

RECTANGLE()
# Out:
# len of rectangle: 2
# brd of rectangle: 2
# area of rectangle is:4

# %%
def CIRCLE_VOLUME():
    
    r=eval(input("radius:"))
    pi=3.14
    volume=pi*r*r*r
    print(f"volume of circle is:{volume}")

CIRCLE_VOLUME()
# Out:
# radius: 1
# volume of circle is:3.14

# %%
def WEIGHT():
    kgs=eval(input("enter the weight in kgs"))
    
    #conversion type
    
    conversion_rate=2.2
    
    pounds=kgs*conversion_rate
    
    print(f"{kgs} kgs in pounds is:{pounds}")

WEIGHT()
# Out:
# enter the weight in kgs 2
# 2 kgs in pounds is:4.4

# %%
def RUPEE():

  d=eval(input('enter the dollars'))
  r=d*85
  print(f"{2} dollars in rupees is:{r}")

RUPEE()
# Out:
# enter the dollars 1
# 2 dollars in rupees is:85

# %% [markdown]
# **Functions with arguments**

# %%
def AVG():     
    n1=eval(input("enter var1") ) #n1= '100'
    n2=eval(input("enter var2"))  #n2= '200'
    n3=eval(input("enter var3"))
    avg=(n1+n2+n3)/3
    print (f"average of numbers is: {avg}") 

AVG()
# Out:
# enter var1 2
# enter var2 2
# enter var3 2
# average of numbers is: 2.0

# %%
def addition3():
       try:
            n1=eval(input('enter the num1:'))
            n2=eval(input('enter the num2:'))
            add1=n1+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)
addition3()
# Out:
# enter the num1: 1
# enter the num2: 2
# the addition of 1 and 2 is:3

# %% [markdown]
#  - 1.  how many variables are there inside the above addn function?
#
#     - 3 variables
#
#     - i.e, **n1,n2,add**
#
#  - 2.  how many input variables are there?
#
#     - input variables means the variables access the values from user as input: **n1,n2**
#
#  - 3.  how many output variables are there?
#
#     - output variable means the variables created because of some operations: **add**
#
#  -    **dont touch the output variable**

# %%
def addition1(n1,n2):
       try:
            add1=n1+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)

# %%
addition1(100,2000)  ##function with arguments
# Out:
# the addition of 100 and 2000 is:2100

# %%
def addition1(n1,n2):
       try:
            print('n1:',n1)
            print('n2:',n2)
            add1=n1+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)

# %%
addition1(20222,22)
# Out:
# n1: 20222
# n2: 22
# the addition of 20222 and 22 is:20244

# %%
def addition4(n1):
       try:
            n2=eval(input('enter the num2:'))
            add1=n1+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)

# %%
addition4(n1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 addition4(n1)
#
# NameError: name 'n1' is not defined

# %%
def addition3():
       try:
            n1=eval(input('enter the num1:'))
            n2=eval(input('enter the num2:'))
            add1=n1+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)
addition3()
########
def addition1(n1,n2):
       try:
            add1=n1+n2
            print(f'the addition of {n1} and {n2} is:{add1}')
       except Exception as e:
           print(e)

addition1(10,29)
# Out:
# enter the num1: 1
# enter the num2: 1
# the addition of 1 and 1 is:2
# the addition of 10 and 29 is:39

# %%
def AVG(n1,n2,n3):     
    n1=eval(input("enter var1") ) #n1= '100'
    n2=eval(input("enter var2") ) #n1= '100'
    n3=eval(input("enter var3") ) #n1= '100'
    avg=(n1+n2+n3)/3
    print (f"average of numbers is: {avg}")

# %%
AVG(10,20,30)
# Out:
# enter var1 10
# enter var2 2
# enter var3 3
# average of numbers is: 5.0

# %% [markdown]
# **Function with the default arguments**

# %%
def BILL():
    bill_amount=eval(input("enter the bill amount"))
    tip_amount=eval(input("enter the tip amount"))
    total_amount= bill_amount+tip_amount
    print(f"Total bill paid is:{total_amount}")

BILL()
# Out:
# enter the bill amount 2000
# enter the tip amount 20
# Total bill paid is:2020

# %%
def BILL1(bill_amount,tip_amount):
   
    
    total_amount= bill_amount+tip_amount
    print(f"Total bill paid is:{total_amount}")

# %%
BILL1(4000,40)
# Out:
# Total bill paid is:4040

# %%
def BILL2(bill_amount,tip_amount=30):
   
    
    total_amount= bill_amount+tip_amount
    print(f"Total bill paid is:{total_amount}")

# %%
BILL2(30000)
# Out:
# Total bill paid is:30030

# %% [markdown]
#  -  in the above function tip_amount is fixed as 30
#
#  -  this is called default arguments
#
#  -  while calling the function no need to provide tip_amount again
#
#  -  if you provide again the value will be changed

# %%
def BILL2(bill_amount,tip_amount=30):
   
    
    total_amount= bill_amount+tip_amount
    print(f"Total bill paid is:{total_amount}")

# %%
BILL2(30000,40)
# Out:
# Total bill paid is:30040

# %%
def AVG(n1,n2,n3=40):     
    
    avg=(n1+n2+n3)/3
    avg1=round(avg,3)
    print (f"average of numbers is: {avg1}") 


AVG(10,20)
# Out:
# average of numbers is: 23.333

# %%
def AVG(n1,n2=50,n3):     
    
    avg=(n1+n2+n3)/3
    avg1=round(avg,3)
    print (f"average of numbers is: {avg1}") 


AVG(10,20)
# Out:
#   Cell In[78], line 1
#     def AVG(n1,n2=50,n3):
#                      ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# **note : default arguments are always at last**

# %%
def AVG(n1,n3,n2=50):     
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    avg1=round(avg,3)
    print (f"average of numbers is: {avg1}") 


AVG(10,20)
# Out:
# n1: 10
# n2: 50
# n3: 20
# average of numbers is: 26.667

# %%
n1,n2,n3=100   #w
n1,n2=100,n3   #f
n1=100,n2,n3   #f 
n1,n2=100,n3=100   #w
n1=100,n2,n3=100   #f
n1=100,n2=100,n3    #f
n1=100,n2=100,n3=100  #w

# %% [markdown]
#  -  Functions with out arguments
#
#  -  Function with arguments
#
#  -  Function with Default arguments

# %%
print("Function With out arguments")
def tax_cal():
 salary=eval(input('enter the salary:'))
 tax_per=eval(input('enter the tax:'))
 tax_pay=salary*tax_per/100
 print("the total tax pay:",tax_pay)
tax_cal()

###
print("Function With arguments")
def tax_cal1(salary,tax_per):
 tax_pay=salary*tax_per/100
 print("the total tax pay:",tax_pay)
tax_cal1(100000,20)

###
print("Function With defualt arguments")
def tax_cal2(salary,tax_per=10):
 tax_pay=salary*tax_per/100
 print("the total tax pay:",tax_pay)
tax_cal2(50000)
# Out:
# Function With out arguments
# enter the salary: 200000
# enter the tax: 20
# the total tax pay: 40000.0
# Function With arguments
# the total tax pay: 20000.0
# Function With defualt arguments
# the total tax pay: 5000.0

# %% [markdown]
# **analogy with the packages**

# %%
from random import randint,random

# %%
random()
tax_cal()
randint()
tax_cal1()

# %%
complex(3,4) # real=3 imag=4 3+4j
# Out:
# (3+4j)

# %%
complex(3) # real=3 imag=0 3+0j In [2]: In [3]
# Out:
# (3+0j)

# %%
complex() # real=0 imag=0 0+0j
# Out:
# 0j

# %% [markdown]
#  -  Now onwards whenever you see any package
#
#  -  always do shift+tab inside the brackets and observe
#
#  -  With or without or default

# %%
def add(a,b,c):
     print('a:',a)
     print('b:',b)
     print('c:',c)
     summ=a+b+c
     print(f'the summation of {a},{b} and {c} is : {summ}')
add(100,200,300)
# Out:
# a: 100
# b: 200
# c: 300
# the summation of 100,200 and 300 is : 600

# %% [markdown]
# **case-1**

# %%
def add(a,b,c=400):
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 print(f'the summation of {a},{b} and {c} is : {summ}')
add(100,200)
# Out:
# a: 100
# b: 200
# c: 400
# the summation of 100,200 and 400 is : 700

# %% [markdown]
# **case_2**

# %%
def add(a,b,c=400):
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 print(f'the summation of {a},{b} and {c} is : {summ}')
add(100,200,600)
# Out:
# a: 100
# b: 200
# c: 600
# the summation of 100,200 and 600 is : 900

# %% [markdown]
#  -  In above case we already provided default value c=400
#
#  -  but while we call the function c value become=600
#
#  -  step-1: Define the function: while define what is the value 400
#
#  -  step-2: call the function: while call the function what is the value 600
#
#  -  step-3: Running the function : while running what is the value : 600

# %%
add1(100,200,600)

def add1(a,b,c=400):
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 print(f'the summation of {a},{b} and {c} is : {summ}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 add1(100,200,600)
#       3 def add1(a,b,c=400):
#       4  print('a:',a)
#
# NameError: name 'add1' is not defined

# %%
def add(a,b,c=400):
 c=1000
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+ccccc
 print(f'the summation of {a},{b} and {c} is : {summ}')

# %%
def add(a,b,c=400):
 c=1000
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 print(f'the summation of {a},{b} and {c} is : {summ}')
add(100,200,600)


# while define c=400
# while calling c=600
# while running c=1000
# Out:
# a: 100
# b: 200
# c: 1000
# the summation of 100,200 and 1000 is : 1300

# %%
def add(a,b,c):
 c=1000  
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 print(f'the summation of {a},{b} and {c} is : {summ}')
add(100,200,600)
# Out:
# a: 100
# b: 200
# c: 1000
# the summation of 100,200 and 1000 is : 1300

# %%
c=3000
def add(a,b,c=600):
     c=1000
     print('a:',a)
     print('b:',b)
     print('c:',c)
     summ=a+b+c
     print(f'the summation of {a},{b} and {c} is : {summ}')
c=2000
add(100,200,800)
# Out:
# a: 100
# b: 200
# c: 1000
# the summation of 100,200 and 1000 is : 1300

# %%
c=3000

def add(a,b):
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 print(f'the summation of {a},{b} and {c} is : {summ}')
add(100,200)


# c=3000
# add() there is no c : c=3000
# call no c : c=3000
# inside the any c : c=3000
# Out:
# a: 100
# b: 200
# c: 3000
# the summation of 100,200 and 3000 is : 3300

# %% [markdown]
# **global variable vs Local variable**
#
#
#  -  The variables outside the function is called as Global variable
#
#  -  Global variables can use anywhere
#
#  -  global variables can be use inside the function also outside the function
#
#  -  The variables inside the function is called as Local variable
#
#  -  local variables can be use only inside function
#
#  -  local variables can not be use outside the function

# %%
def addition():
 n1=100
 n2=200
 summ=n1+n2
 print(f'the summation of {n1},{n2} is : {summ}')
addition()
# Out:
# the summation of 100,200 is : 300

# %%
n1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 n1
#
# NameError: name 'n1' is not defined

# %%
n1=1000
n2=3000
def addition():
 summ=n1+n2
 print(f'the summation of {n1},{n2} is : {summ}')
addition()
# Out:
# the summation of 1000,3000 is : 4000

# %%
n1
# Out:
# 1000

# %% [markdown]
# **How to convert local variable to Global variable**
#
#  -  if we want to use summ variable outside the function
#
#  -  Then intialise summ as global also using global keyword

# %%
n1=1000
n2=2000
def addition():
 global summ
 summ=n1+n2
 print(f'the summation of {n1},{n2} is : {summ}')
addition()
# Out:
# the summation of 1000,2000 is : 3000

# %%
summ
# Out:
# 3000

# %% [markdown]
# **unbound local error**
#
#  -  in below example s is not intialised
#
#  - we might think name error will come
#
#  -  but inside function we will get unbound local error

# %%
def add1():
 n1=100
 summ1=summ1+n1 
 print(s1)
add1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[84], line 5
#       3  summ1=summ1+n1
#       4  print(s1)
# ----> 5 add1()
#
# Cell In[84], line 3, in add1()
#       1 def add1():
#       2  n1=100
# ----> 3  summ1=summ1+n1
#       4  print(s1)
#
# UnboundLocalError: cannot access local variable 'summ1' where it is not associated with a value

# %%
def add1():
 n1=100
 s1=summ1+n1 
 print(s1)
add1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 5
#       3  s1=summ1+n1
#       4  print(s1)
# ----> 5 add1()
#
# Cell In[86], line 3, in add1()
#       1 def add1():
#       2  n1=100
# ----> 3  s1=summ1+n1
#       4  print(s1)
#
# NameError: name 'summ1' is not defined

# %%
def add1():
 n1=100
 s1=summ1+n1 
 print(s1)
add1() # Name error summ1
####################################
def add1():
 n1=100
 summ1=summ1+n1 
 print(s1)
add1() # unbound local
###################################
def add1():
 summ1=0
 n1=100
 s1=summ1+n1 
 print(s1)
add1()
############################################
def add1():
 n1=100
 summ1=0
 summ1=summ1+n1 
 print(s1)
add1()

# %%
##################################
def add1():
 summ1=0
 n1=100
 s1=summ1+n1 
 print(s1)
add1()
# Out:
# 100

# %%
def add2():
 n1=100
 summ1=0
 summ1=summ1+n1 
 print(s1)
add2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 6
#       4  summ1=summ1+n1
#       5  print(s1)
# ----> 6 add2()
#
# Cell In[102], line 5, in add2()
#       3 summ1=0
#       4 summ1=summ1+n1
# ----> 5 print(s1)
#
# NameError: name 's1' is not defined

# %%
def add3():
 n1=100
 summ2=100
 summ2=summ2+n1 
 print(summ2)
add3()
# Out:
# 200

# %%
def avg(a,b,c):
 global ADD,AVG1
 ADD=a+b+c
 AVG1=ADD/3
 print(ADD,AVG1)
avg(10,20,30)
# Out:
# 60 20.0

# %%
ADD,AVG1
# Out:
# (60, 20.0)

# %%
C=3000
def add(a,b):
     print('a:',a)
     print('b:',b)
     print('c:',c)
     summ=a+b+c
     print(f'the summation of {a},{b} and {c} is : {summ}')
c=5000

add(100,200)

# st-1: c=3000
# st-2: def
# st-3: c=5000
# st-4: call
# st-5: run
# Out:
# a: 100
# b: 200
# c: 5000
# the summation of 100,200 and 5000 is : 5300

# %%
c=3000
def add(a,b):
 c=7000
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 c=8000
 print(f'the summation of {a},{b} and {c} is : {summ}')
c=5000
add(100,200)
# Out:
# a: 100
# b: 200
# c: 7000
# the summation of 100,200 and 8000 is : 7300

# %%
c=3000
def add(a,b,c=10000):
 print('a:',a)
 print('b:',b)
 print('c:',c)
 summ=a+b+c
 c=8000
 print(f'the summation of {a},{b} and {c} is : {summ}')
c=5000
add(100,200,9000)
# Out:
# a: 100
# b: 200
# c: 9000
# the summation of 100,200 and 8000 is : 9300

# %%
a=10
b=20
a,b=b,a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
#  -  functions with out arguments
#
#  -  Function with arguments
#
#  -  Function default arguments
#
#  -  Local vs global variable

# %%
# wap ask the user enter a number
# print it is an even or odd
#a) Function with out argument with default

# %%
def even_odd():
     num=eval(input('enter a num:'))
     if num%2==0:
         print(f'{num} is an even')
     else:
         print(f'{num} is an odd')
even_odd()
# Out:
# enter a num: 28
# 28 is an even

# %%
def even_odd1(num):
     if num%2==0:
         print(f'{num} is an even')
     else:
         print(f'{num} is an odd')
even_odd1(101)
# Out:
# 101 is an odd

# %%
def even_odd2(num1=202):
     global num1
     if num1%2==0:
         print(f'{num1} is an even')
     else:
         print(f'{num1} is an odd')
even_odd2()
# Out:
#   Cell In[21], line 2
#     global num1
#     ^
# SyntaxError: name 'num1' is parameter and global

# %%
num1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 num1
#
# NameError: name 'num1' is not defined

# %%
def even_odd():
     global num2
     num2=eval(input('enter a num:'))
     if num2%2==0:
         print(f'{num2} is an even')
     else:
         print(f'{num2} is an odd')

even_odd()
# Out:
# enter a num: 208
# 208 is an even

# %%
num2
# Out:
# 208

# %%
def even_odd2(num1=202):
     global num1
     if num1%2==0:
         print(f'{num1} is an even')
     else:
         print(f'{num1} is an odd')
even_odd2()


def even_odd():
     global num2
     num2=eval(input('enter a num:'))
     if num2%2==0:
         print(f'{num2} is an even')
     else:
         print(f'{num2} is an odd')
even_odd()

# %% [markdown]
# **parameter vs Variable**
#
#  -  Parameters also called as Arguments
#
#      - This always inside the function brackets
#
#  -  Varaibles either outside the function or inside the functio

# %% [markdown]
# **return**
#
# - return means function is giving something
#
# - we know that local variables can not use outside the function
#
# - in orderto use local varaibles outside the function , we have two methods
#
# - global
#
# - return

# %%
def add():
 a=10
 b=20
 c=a+b
 return(c)
c=add()

# %%
value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 value
#
# NameError: name 'value' is not defined

# %%
c
# Out:
# 30

# %%
value=10,20 # conf
val1,val2=10,20 # works
val1,val2=10 # fail

# %%
value=10,20
value # tuple
# Out:
# (10, 20)

# %%
val1,val2=10,20
val1
# Out:
# 10

# %%
val2
# Out:
# 20

# %%
val1,val2=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 val1,val2=10
#
# TypeError: cannot unpack non-iterable int object

# %%
def add():
 a=10
 b=20
 c=a+b
 return(a,c)
a,c=add()
print(a)
print(c)
# Out:
# 10
# 30

# %%
a
# Out:
# 10

# %%
def avg(a,b,c):
 summ=a+b+c
 AVG=summ/3
 return(summ,AVG)
summ,AVG=avg(10,20,30)
print(summ)
print(AVG)
# Out:
# 60
# 20.0

# %%
def even_odd():
     num2=eval(input('enter a num:'))
     if num2%2==0:
         val=10
         print(f'{num2} is an even')
         return(num2+10)
     else:
         val=20
         print(f'{num2} is an odd')
         return(num2+20)
output=even_odd()
print(output)
# Out:
# enter a num: 20
# 20 is an even
# 30

# %%
def even_odd():
     num2=eval(input('enter a num:'))
     if num2%2==0:
         val=10
         print(f'{num2} is an even')
     else:
         val=20
         print(f'{num2} is an odd')
         return(num2)
output=even_odd()
print(output)
# Out:
# enter a num: 20
# 20 is an even
# None

# %%
def func_event_odd2(n1):
 # n1=eval(input('Enter the number :'))
 if n1%2==0:
     return('Event Number')
 else:
     return('Odd Number')
Event_Odd = func_event_odd2(71)

# %%
print (Event_Odd)
# Out:
# Odd Number

# %% [markdown]
# **function in function**

# %%
def greet1():
     print('hello good morning')
    
def greet2():
     print('hello good night')
    
greet1()
greet2()
# Out:
# hello good morning
# hello good night

# %%
def greet1():
     print('hello good morning')

def greet2():
     print('hello good night')
     greet1()
    
greet2()
# Out:
# hello good night
# hello good morning

# %%
def greet11():
     print('hello good morning')
     greet22() # first time seeing error
    
def greet22():
     print('hello good night')
    
greet11()
# Out:
# hello good morning
# hello good night

# %%
def greet11():
 print('hello good morning')
 greet22() # first time seeing error
def greet22():
 print('hello good night')
 greet11()
greet11()

# %%
def greet3():
 print('i dont know what im doing')
 greet3()
greet3()
# Out:
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# ...
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# i dont know what im doing
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[113], line 4
#       2  print('i dont know what im doing')
#       3  greet3()
# ----> 4 greet3()
#
# Cell In[113], line 3, in greet3()
#       1 def greet3():
#       2  print('i dont know what im doing')
# ----> 3  greet3()
#
# Cell In[113], line 3, in greet3()
#       1 def greet3():
#       2  print('i dont know what im doing')
# ----> 3  greet3()
#
#     [... skipping similar frames: greet3 at line 3 (2972 times)]
#
# Cell In[113], line 3, in greet3()
#       1 def greet3():
#       2  print('i dont know what im doing')
# ----> 3  greet3()
#
# Cell In[113], line 2, in greet3()
#       1 def greet3():
# ----> 2  print('i dont know what im doing')
#       3  greet3()
#
# File ~\anaconda3\Lib\site-packages\ipykernel\iostream.py:649, in OutStream.write(self, string)
#     646     msg = "I/O operation on closed file"
#     647     raise ValueError(msg)
# --> 649 is_child = not self._is_master_process()
#     650 # only touch the buffer in the IO thread to avoid races
#     651 with self._buffer_lock:
#
# RecursionError: maximum recursion depth exceeded

# %%
5
5+4 ======= 5+(5-1)
5+4+3 ===== 5+4+(4-1)
5+4+3+2
5+4+3+2+1
5+4+3+2+1+0
n+n-1

# %%
def add(n):
     if n==0:
         return(0)
     else:
         return(n+add(n-1))
add(5)
step-1: n=5 if F else 5+add(4)
 5+4+add(3)
 5+4+3+add(2)
 5+4+3+2+add(1)
 5+4+3+2+1+add(0)
 5+4+3+2+1+0

# %%
def add(n):
 if n==0:
     return(0)
 else:
     return(n+add(n-1))
add(5)
# Out:
# 15

# %%
# Q1) Factorial recursion 5! = 5*4*3*2*1*
# Q2) calcultor
# step-1: create 4 functions
# def add(a,b):
# return(a+b)
# def mul
# def div
# def sub
# print('enter 1 for add 2 sub so on')

# %%
# Q1) Factorial recursion 5! = 5*4*3*2*1*

def fac(n):
     if n==0:
         return 1
     else:
         return (n*(fac(n-1)))
         
fac(3)
# Out:
# 6

# %%
# Q2) calcultor
# step-1: create 4 functions
# def add(a,b):
# return(a+b)
# def mul
# def div
# def sub
# print('enter 1 for add 2 sub so on')
def main():
   
    oper=eval(input('enter the number 1-5:'))
    if oper==1:
        n1=eval(input('enter the number:'))
        n2=eval(input('enter the number:'))
        add=n1+n2
        return('add')
   
    elif oper==2:
        n1=eval(input('enter the number:'))
        n2=eval(input('enter the number:'))
        sub=n1-n2
        return('sub')
   
    elif oper==3:
        n1=eval(input('enter the number:'))
        n2=eval(input('enter the number:'))
        mul=n1*n2
        return('mul')
   
    elif oper==4:
        n1=eval(input('enter the number:'))
        n2=eval(input('enter the number:'))
        div=n1/n2
        return('div')
   
    else:
        return('incorrect operation')

main()
# Out:
# enter the number 1-5: 3
# enter the number: 2
# enter the number: 3
# 'mul'
