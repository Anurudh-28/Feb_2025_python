# %% [markdown]
# import os
# os.getcwd()
# #get current workin directory

# %%
# checkpoint-1:

#empty sqaure bracket before the code cell

#indicates we did not run the cell

#checkpoint-2

# if we see a * mark inside square bracket do not run the next code cell

#  * mark indicates kernal is busy

#the same we can observe top left corner black dot

# %%
number=28

# %%
number
# Out:
# 28

# %% [markdown]
# hello today iam learning python
#
# square bracket is there : yes
#
# code mode is there : yes
#
# if these two modes are there which indicates this current cell is used for write code only
#
# if you write english i will throw error
#
# go to top code mode after a drop down symbol is there
#
# click on that
#
# we can see markdown option
#
# select it that we can not see any square bracket

# %% [markdown]
# # python

# %% [markdown]
# #python
#
# - esc+m will change code mode to markdown mode
#
# - shift+enter

# %%
#anurudh

 - esc+y will change markdown mode to code mode

 - shift+enter

 # biet
 ## biet
 ### biet

# %% [markdown]
#  # biet
#  ## biet
#  ### biet

# %% [markdown]
# **now i will show how to upload image**

# %% [markdown]
# <img id="dimg_qXZzZ-fUCbvF4-EPnNGW8Qs_211" src="data:image/jpeg;base64,..." class="YQ4gaf" height="194" style="object-position:12% 12%" width="259" alt="vs code for Python coding ..." data-csiid="qXZzZ-fUCbvF4-EPnNGW8Qs_12" data-atf="1">

# %%
go to google chrome

inspect on image

select the image id

edit as html

ctrl+a

ctrl+c

cominng to notebook

crct+v

esc+m

shift+enter

# %% [markdown]
# <img id="dimg_qXZzZ-fUCbvF4-EPnNGW8Qs_211" src="data:image/jpeg;base64,..." class="YQ4gaf" height="194" style="object-position:12% 12%" width="259" alt="vs code for Python coding ..." data-csiid="qXZzZ-fUCbvF4-EPnNGW8Qs_12" data-atf="1">

# %% [markdown]
# <img src="https://i.pinimg.com/736x/51/cb/37/51cb379ada79dfc6339a4f88a8946357.jpg" alt="Prabhas HD images | Prabhas pics, Prabhas actor, New movie images" class=" nofocus" tabindex="0" aria-label="Prabhas HD images | Prabhas pics, Prabhas actor, New movie images" role="button">
